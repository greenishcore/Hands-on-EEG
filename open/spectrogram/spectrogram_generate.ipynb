# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy import signal

# %%
data = pd.read_csv("C:\\Users\\a1882\\Desktop\\EEG\\eegdata_3000\\slice_data\\lefthand_zyy_04_epocflex_2023.03.22t16.48.29+08.00.md.bp.csv_0.csv")

# %%
ch = data.iloc[0,:]
print(ch)
# Out:
# 0       -60.042149
# 1       -80.474419
# 2       -80.906250
# 3       -77.751495
# 4      -102.776825
#            ...
# 2995     10.910384
# 2996     26.781012
# 2997     -5.521153
# 2998     -6.027940
# 2999     26.765779
# Name: 0, Length: 3000, dtype: float64

# %%
freq = 128
t = np.arange(0, 3000/freq , 1/freq)
signal = ch.to_numpy()

freq,t,Sxx = scipy.signal.spectrogram(signal, freq)

amplitude = np.abs(Sxx)

fig = plt.figure(figsize=(10, 10))

plt.pcolormesh(t, freq, np.log(amplitude), shading='gouraud')
plt.axis('off')
fig.patch.set_visible(False)

fig.savefig('C:/Users/a1882/Desktop/EEG/eegdata_3000/spectrogram/spectrogram.png',bbox_inches='tight',pad_inches=0)

# %%
import torch
freq = 128
t = np.arange(0, 3000/freq , 1/freq)
signal = ch.to_numpy()
# print(t)
freq,t,Sxx = scipy.signal.spectrogram(signal, freq)

amplitude = np.abs(Sxx)
out = np.log(amplitude)
# print(Sxx)
# Sxx
# print(t)
#signal.shape
# print(out)

#amplitude.shape
#out.shape
plt.axis('off')
fig.patch.set_visible(False)
pic = plt.pcolormesh(t, freq, np.log(amplitude), shading='gouraud')
img_np = np.array(pic.get_array())
# print(img_np)
img_tensor = torch.from_numpy(img_np)

# %%
size = os.path.getsize('C:/Users/a1882/Desktop/EEG/eegdata_3000/spectrogram/spectrogram.png')
width, height = plt.imread('C:/Users/a1882/Desktop/EEG/eegdata_3000/spectrogram/spectrogram.png').shape[:2]
print(f'图片大小为{size}字节，长为{width}像素，宽为{height}像素。')
# Out:
# 图片大小为288658字节，长为770像素，宽为775像素。

# %%
# file_lsit = os.listdir('C:/Users/a1882/Desktop/EEG/eegdata_3000/slice_data')
# save_path = os.getcwd()
# os.chdir('C:/Users/a1882/Desktop/EEG/eegdata_3000/slice_data')
#
# input_file = 'C:/Users/a1882/Desktop/EEG/eegdata_3000/slice_data'
# output_file = 'C:/Users/a1882/Desktop/EEG/eegdata_3000/spectrogram'
#
# for file in file_lsit:
#     for i in range(32):
#         freq = 128
#         t = np.arange(0, 3000/freq , 1/freq)
#         signal = data.iloc[i,:].to_numpy()
#         freq,t,Sxx = scipy.signal.spectrogram(signal, freq)
#         amplitude = np.abs(Sxx)
#         fig = plt.figure(figsize=(10, 10))
#         plt.pcolormesh(t, freq, np.log(amplitude), shading='gouraud')
#         plt.axis('off')
#         fig.patch.set_visible(False)
#         # plt.show()
#         fig.savefig(f'C:/Users/a1882/Desktop/EEG/eegdata_3000/spectrogram/{file}_{i}.png',bbox_inches='tight',pad_inches=0)
#         plt.close()
#
# os.chdir(save_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\PIL\ImageFile.py:518, in _save(im, fp, tile, bufsize)
#     517 try:
# --> 518     fh = fp.fileno()
#     519     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      18         fig.patch.set_visible(False)
#      19         # plt.show()
# ---> 20         fig.savefig(f'C:/Users/a1882/Desktop/EEG/eegdata_3000/spectrogram/{file}_{i}.png',bbox_inches='tight',pad_inches=0)
#      21         plt.close()
#      23 os.chdir(save_path)
#
# ...
