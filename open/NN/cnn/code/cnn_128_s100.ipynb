# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import random_split
from torch.optim.lr_scheduler import StepLR

# %%
origin_raw_data_dir = 'C:\\Users\\a1882\Desktop\EEG\open\\NN\dataset\\128_s100'
model_save ='C:\\Users\\a1882\\Desktop\\EEG\\normal\\model'
pic_dir = 'C:\\Users\\a1882\\Desktop\\EEG\\normal\\pic'

# %%
class EEG_Dataset(Dataset):
    def __init__(self, data_dir):
        self.data_dir = origin_raw_data_dir
        self.file_list = os.listdir(self.data_dir)

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_name = self.file_list[idx]
        file_path = os.path.join(self.data_dir, file_name)
        data = pd.read_csv(file_path, header=None)
        data = data.values
        data = torch.from_numpy(data)
        label_map = {'lefthand': 0, 'read': 1, 'rest': 2, 'walkbase': 3, 'walkl': 4 ,'walkfocus': 5}
        data_label = label_map[file_name.split('_')[0]]
        return data, data_label

# %%
dataset = EEG_Dataset(origin_raw_data_dir)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=4096, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=4096, shuffle=False)

# %%
class EEGNet(nn.Module):
    def __init__(self, num_classes=6):
        super(EEGNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=(1, 4), stride=(1, 2))
        self.bn1 = nn.BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.pool1 = nn.MaxPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout1 = nn.Dropout(p=0.25)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(1, 2), stride=(1, 2))
        self.bn2 = nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.pool2 = nn.MaxPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout2 = nn.Dropout(p=0.25)
        self.fc1 = nn.Linear(1024, 128)
        self.dropout3 = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(128, 6)


    def forward(self, x):
        x = torch.unsqueeze(x, 1)
        print('x:', x.shape)
        x = self.conv1(x)
        print('conv1:', x.shape)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.pool1(x)
        print('pool1:', x.shape)
        x = self.dropout1(x)
        x = self.conv2(x)
        print('conv2:', x.shape)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.pool2(x)
        print('pool2:', x.shape)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        print('flatten:', x.shape)
        x = self.fc1(x)
        print('fc1:', x.shape)
        x = torch.relu(x)
        x = self.dropout3(x)
        x = self.fc2(x)
        print('fc2:', x.shape)
        return x

# %%
X = torch.randn(size=( 1, 32, 128), dtype=torch.float32)
model = EEGNet()
output = model(X)
print(output.shape)
# Out:
# x: torch.Size([1, 1, 32, 128])
# conv1: torch.Size([1, 16, 32, 63])
# pool1: torch.Size([1, 16, 32, 15])
# conv2: torch.Size([1, 32, 32, 7])
# pool2: torch.Size([1, 32, 32, 1])
# flatten: torch.Size([1, 1024])
# fc1: torch.Size([1, 128])
# fc2: torch.Size([1, 6])
# torch.Size([1, 6])

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.cuda.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
learning_rate = 0.001
num_epochs = 200
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=50, gamma=0.1)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction error
        pred = model(X.float())
        loss = loss_fn(pred, y)
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
            global train_loss
            train_loss.append(loss)



def test(dataloader, model,loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X.float())
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error:\n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    global valid_loss
    valid_loss.append(test_loss)
    global accuracy
    accuracy.append(correct)

# %%
#torch.cuda.empty_cache()
#model = model.cuda()
train_loss = []
valid_loss = []
accuracy = []
for t in range(num_epochs):
    print(f"Epoch {t + 1}\n-------------------------------")
    model.train(True)
    train(train_loader, model, loss_fn, optimizer)

    model.train(False)
    test(test_loader, model, loss_fn)

    if t > num_epochs-5:
        torch.save(model.state_dict(), os.path.join(model_save,'cnn_128_100e_'+str(t)+'.pt'))

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.797559  [    0/ 3788]
# Test Error:
#  Accuracy: 25.1%, Avg loss: 1.671532
#
# Epoch 2
# -------------------------------
# loss: 1.609870  [    0/ 3788]
# Test Error:
#  Accuracy: 25.4%, Avg loss: 1.618400
#
# Epoch 3
# -------------------------------
# loss: 1.518554  [    0/ 3788]
# Test Error:
#  Accuracy: 32.4%, Avg loss: 1.576082
#
# Epoch 4
# -------------------------------
# loss: 1.420602  [    0/ 3788]
# Test Error:
#  Accuracy: 49.3%, Avg loss: 1.529740
#
# Epoch 5
# -------------------------------
# loss: 1.336463  [    0/ 3788]
# Test Error:
#  Accuracy: 55.8%, Avg loss: 1.479656
#
# Epoch 6
# -------------------------------
# loss: 1.244465  [    0/ 3788]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 1.429071
#
# Epoch 7
# -------------------------------
# loss: 1.170379  [    0/ 3788]
# Test Error:
#  Accuracy: 61.5%, Avg loss: 1.376812
#
# Epoch 8
# -------------------------------
# loss: 1.122537  [    0/ 3788]
# Test Error:
#  Accuracy: 64.4%, Avg loss: 1.326168
#
# Epoch 9
# -------------------------------
# loss: 1.053604  [    0/ 3788]
# Test Error:
#  Accuracy: 67.1%, Avg loss: 1.273130
#
# Epoch 10
# -------------------------------
# loss: 1.006510  [    0/ 3788]
# Test Error:
#  Accuracy: 69.4%, Avg loss: 1.217743
#
# Epoch 11
# -------------------------------
# loss: 0.965127  [    0/ 3788]
# Test Error:
#  Accuracy: 72.1%, Avg loss: 1.161271
#
# Epoch 12
# -------------------------------
# loss: 0.926771  [    0/ 3788]
# Test Error:
#  Accuracy: 73.7%, Avg loss: 1.110215
#
# Epoch 13
# -------------------------------
# loss: 0.872287  [    0/ 3788]
# Test Error:
#  Accuracy: 74.0%, Avg loss: 1.064086
#
# Epoch 14
# -------------------------------
# loss: 0.847215  [    0/ 3788]
# Test Error:
#  Accuracy: 74.1%, Avg loss: 1.015147
#
# Epoch 15
# -------------------------------
# loss: 0.801175  [    0/ 3788]
# Test Error:
#  Accuracy: 75.1%, Avg loss: 0.967540
#
# Epoch 16
# -------------------------------
# loss: 0.787264  [    0/ 3788]
# Test Error:
#  Accuracy: 75.1%, Avg loss: 0.926359
#
# Epoch 17
# -------------------------------
# loss: 0.753906  [    0/ 3788]
# Test Error:
#  Accuracy: 75.7%, Avg loss: 0.889946
#
# Epoch 18
# -------------------------------
# loss: 0.733865  [    0/ 3788]
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.857491
#
# Epoch 19
# -------------------------------
# loss: 0.699460  [    0/ 3788]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.827529
#
# Epoch 20
# -------------------------------
# loss: 0.680271  [    0/ 3788]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.800124
#
# Epoch 21
# -------------------------------
# loss: 0.660410  [    0/ 3788]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.773673
#
# Epoch 22
# -------------------------------
# loss: 0.632600  [    0/ 3788]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.748466
#
# Epoch 23
# -------------------------------
# loss: 0.623334  [    0/ 3788]
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.724723
#
# Epoch 24
# -------------------------------
# loss: 0.591472  [    0/ 3788]
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.702207
#
# Epoch 25
# -------------------------------
# loss: 0.588229  [    0/ 3788]
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.681161
#
# Epoch 26
# -------------------------------
# loss: 0.562376  [    0/ 3788]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.662238
#
# Epoch 27
# -------------------------------
# loss: 0.536417  [    0/ 3788]
# Test Error:
#  Accuracy: 82.6%, Avg loss: 0.643361
#
# Epoch 28
# -------------------------------
# loss: 0.536316  [    0/ 3788]
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.624605
#
# Epoch 29
# -------------------------------
# loss: 0.515473  [    0/ 3788]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.607305
#
# Epoch 30
# -------------------------------
# loss: 0.502080  [    0/ 3788]
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.590630
#
# Epoch 31
# -------------------------------
# loss: 0.491295  [    0/ 3788]
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.574342
#
# Epoch 32
# -------------------------------
# loss: 0.476080  [    0/ 3788]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.559226
#
# Epoch 33
# -------------------------------
# loss: 0.466874  [    0/ 3788]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.545429
#
# Epoch 34
# -------------------------------
# loss: 0.462003  [    0/ 3788]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.533869
#
# Epoch 35
# -------------------------------
# loss: 0.453505  [    0/ 3788]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.524043
#
# Epoch 36
# -------------------------------
# loss: 0.434367  [    0/ 3788]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.516447
#
# Epoch 37
# -------------------------------
# loss: 0.423145  [    0/ 3788]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.508845
#
# Epoch 38
# -------------------------------
# loss: 0.423832  [    0/ 3788]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.498237
#
# Epoch 39
# -------------------------------
# loss: 0.413255  [    0/ 3788]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.484659
#
# Epoch 40
# -------------------------------
# loss: 0.407696  [    0/ 3788]
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.470390
#
# Epoch 41
# -------------------------------
# loss: 0.390253  [    0/ 3788]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.456128
#
# Epoch 42
# -------------------------------
# loss: 0.380323  [    0/ 3788]
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.442359
#
# Epoch 43
# -------------------------------
# loss: 0.383578  [    0/ 3788]
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.428461
#
# Epoch 44
# -------------------------------
# loss: 0.374029  [    0/ 3788]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.415592
#
# Epoch 45
# -------------------------------
# loss: 0.369491  [    0/ 3788]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.403166
#
# Epoch 46
# -------------------------------
# loss: 0.360443  [    0/ 3788]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.391926
#
# Epoch 47
# -------------------------------
# loss: 0.351663  [    0/ 3788]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.381560
#
# Epoch 48
# -------------------------------
# loss: 0.341114  [    0/ 3788]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.372814
#
# Epoch 49
# -------------------------------
# loss: 0.333619  [    0/ 3788]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.365245
#
# Epoch 50
# -------------------------------
# loss: 0.339146  [    0/ 3788]
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.359246
#
# Epoch 51
# -------------------------------
# loss: 0.321360  [    0/ 3788]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.353158
#
# Epoch 52
# -------------------------------
# loss: 0.321052  [    0/ 3788]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.347045
#
# Epoch 53
# -------------------------------
# loss: 0.317832  [    0/ 3788]
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.340523
#
# Epoch 54
# -------------------------------
# loss: 0.323079  [    0/ 3788]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.335116
#
# Epoch 55
# -------------------------------
# loss: 0.311860  [    0/ 3788]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.329738
#
# Epoch 56
# -------------------------------
# loss: 0.298880  [    0/ 3788]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.323845
#
# Epoch 57
# -------------------------------
# loss: 0.295209  [    0/ 3788]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.317130
#
# Epoch 58
# -------------------------------
# loss: 0.295212  [    0/ 3788]
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.309403
#
# Epoch 59
# -------------------------------
# loss: 0.287594  [    0/ 3788]
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.301349
#
# Epoch 60
# -------------------------------
# loss: 0.293358  [    0/ 3788]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.294234
#
# Epoch 61
# -------------------------------
# loss: 0.287783  [    0/ 3788]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.287594
#
# Epoch 62
# -------------------------------
# loss: 0.278744  [    0/ 3788]
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.281962
#
# Epoch 63
# -------------------------------
# loss: 0.281281  [    0/ 3788]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.276424
#
# Epoch 64
# -------------------------------
# loss: 0.276827  [    0/ 3788]
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.271507
#
# Epoch 65
# -------------------------------
# loss: 0.271473  [    0/ 3788]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.266771
#
# Epoch 66
# -------------------------------
# loss: 0.268007  [    0/ 3788]
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.261923
#
# Epoch 67
# -------------------------------
# loss: 0.260873  [    0/ 3788]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.257676
#
# Epoch 68
# -------------------------------
# loss: 0.258864  [    0/ 3788]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.254357
#
# Epoch 69
# -------------------------------
# loss: 0.261740  [    0/ 3788]
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.251217
#
# Epoch 70
# -------------------------------
# loss: 0.252753  [    0/ 3788]
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.248026
#
# Epoch 71
# -------------------------------
# loss: 0.249603  [    0/ 3788]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.244439
#
# Epoch 72
# -------------------------------
# loss: 0.245585  [    0/ 3788]
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.241169
#
# Epoch 73
# -------------------------------
# loss: 0.247324  [    0/ 3788]
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.238792
#
# Epoch 74
# -------------------------------
# loss: 0.237402  [    0/ 3788]
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.236734
#
# Epoch 75
# -------------------------------
# loss: 0.238492  [    0/ 3788]
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.233582
#
# Epoch 76
# -------------------------------
# loss: 0.237797  [    0/ 3788]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.230316
#
# Epoch 77
# -------------------------------
# loss: 0.243954  [    0/ 3788]
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.227284
#
# Epoch 78
# -------------------------------
# loss: 0.240306  [    0/ 3788]
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.224828
#
# Epoch 79
# -------------------------------
# loss: 0.230291  [    0/ 3788]
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.222297
#
# Epoch 80
# -------------------------------
# loss: 0.223494  [    0/ 3788]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.219694
#
# Epoch 81
# -------------------------------
# loss: 0.237501  [    0/ 3788]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.216876
#
# Epoch 82
# -------------------------------
# loss: 0.229488  [    0/ 3788]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.214653
#
# Epoch 83
# -------------------------------
# loss: 0.226268  [    0/ 3788]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.212379
#
# Epoch 84
# -------------------------------
# loss: 0.220745  [    0/ 3788]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.210370
#
# Epoch 85
# -------------------------------
# loss: 0.232080  [    0/ 3788]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.208602
#
# Epoch 86
# -------------------------------
# loss: 0.207654  [    0/ 3788]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.206849
#
# Epoch 87
# -------------------------------
# loss: 0.213403  [    0/ 3788]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.205385
#
# Epoch 88
# -------------------------------
# loss: 0.202085  [    0/ 3788]
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.203714
#
# Epoch 89
# -------------------------------
# loss: 0.207212  [    0/ 3788]
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.202560
#
# Epoch 90
# -------------------------------
# loss: 0.209599  [    0/ 3788]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.202014
#
# Epoch 91
# -------------------------------
# loss: 0.210252  [    0/ 3788]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.201107
#
# Epoch 92
# -------------------------------
# loss: 0.205057  [    0/ 3788]
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.199283
#
# Epoch 93
# -------------------------------
# loss: 0.203929  [    0/ 3788]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.198300
#
# Epoch 94
# -------------------------------
# loss: 0.209002  [    0/ 3788]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.198016
#
# Epoch 95
# -------------------------------
# loss: 0.200615  [    0/ 3788]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.195914
#
# Epoch 96
# -------------------------------
# loss: 0.203637  [    0/ 3788]
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.193984
#
# Epoch 97
# -------------------------------
# loss: 0.197466  [    0/ 3788]
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.192707
#
# Epoch 98
# -------------------------------
# loss: 0.194626  [    0/ 3788]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.189054
#
# Epoch 99
# -------------------------------
# loss: 0.196369  [    0/ 3788]
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.183989
#
# Epoch 100
# -------------------------------
# loss: 0.198007  [    0/ 3788]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.180176
#
# Epoch 101
# -------------------------------
# loss: 0.192410  [    0/ 3788]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.176887
#
# Epoch 102
# -------------------------------
# loss: 0.189967  [    0/ 3788]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.174020
#
# Epoch 103
# -------------------------------
# loss: 0.186350  [    0/ 3788]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.173432
#
# Epoch 104
# -------------------------------
# loss: 0.188681  [    0/ 3788]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.175251
#
# Epoch 105
# -------------------------------
# loss: 0.189376  [    0/ 3788]
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.173803
#
# Epoch 106
# -------------------------------
# loss: 0.182243  [    0/ 3788]
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.170003
#
# Epoch 107
# -------------------------------
# loss: 0.182578  [    0/ 3788]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.167722
#
# Epoch 108
# -------------------------------
# loss: 0.182688  [    0/ 3788]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.166631
#
# Epoch 109
# -------------------------------
# loss: 0.179276  [    0/ 3788]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.165490
#
# Epoch 110
# -------------------------------
# loss: 0.174336  [    0/ 3788]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.165880
#
# Epoch 111
# -------------------------------
# loss: 0.181161  [    0/ 3788]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.166521
#
# Epoch 112
# -------------------------------
# loss: 0.176959  [    0/ 3788]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.164574
#
# Epoch 113
# -------------------------------
# loss: 0.173348  [    0/ 3788]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.160844
#
# Epoch 114
# -------------------------------
# loss: 0.175659  [    0/ 3788]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.158359
#
# Epoch 115
# -------------------------------
# loss: 0.174578  [    0/ 3788]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.157638
#
# Epoch 116
# -------------------------------
# loss: 0.166717  [    0/ 3788]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.157075
#
# Epoch 117
# -------------------------------
# loss: 0.165257  [    0/ 3788]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.157267
#
# Epoch 118
# -------------------------------
# loss: 0.169655  [    0/ 3788]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.157260
#
# Epoch 119
# -------------------------------
# loss: 0.172956  [    0/ 3788]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.156699
#
# Epoch 120
# -------------------------------
# loss: 0.168298  [    0/ 3788]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.153027
#
# Epoch 121
# -------------------------------
# loss: 0.168828  [    0/ 3788]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.149736
#
# Epoch 122
# -------------------------------
# loss: 0.166317  [    0/ 3788]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.147119
#
# Epoch 123
# -------------------------------
# loss: 0.164476  [    0/ 3788]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.145769
#
# Epoch 124
# -------------------------------
# loss: 0.165024  [    0/ 3788]
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.145534
#
# Epoch 125
# -------------------------------
# loss: 0.157291  [    0/ 3788]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.145087
#
# Epoch 126
# -------------------------------
# loss: 0.153787  [    0/ 3788]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.143649
#
# Epoch 127
# -------------------------------
# loss: 0.154185  [    0/ 3788]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.141394
#
# Epoch 128
# -------------------------------
# loss: 0.160702  [    0/ 3788]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.140172
#
# Epoch 129
# -------------------------------
# loss: 0.159132  [    0/ 3788]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.140258
#
# Epoch 130
# -------------------------------
# loss: 0.155449  [    0/ 3788]
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.140446
#
# Epoch 131
# -------------------------------
# loss: 0.156943  [    0/ 3788]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.139999
#
# Epoch 132
# -------------------------------
# loss: 0.155863  [    0/ 3788]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.137946
#
# Epoch 133
# -------------------------------
# loss: 0.158996  [    0/ 3788]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.135645
#
# Epoch 134
# -------------------------------
# loss: 0.161006  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.134736
#
# Epoch 135
# -------------------------------
# loss: 0.156398  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.134875
#
# Epoch 136
# -------------------------------
# loss: 0.155294  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.135086
#
# Epoch 137
# -------------------------------
# loss: 0.161517  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.134928
#
# Epoch 138
# -------------------------------
# loss: 0.144277  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.135693
#
# Epoch 139
# -------------------------------
# loss: 0.146226  [    0/ 3788]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.135494
#
# Epoch 140
# -------------------------------
# loss: 0.143856  [    0/ 3788]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.134137
#
# Epoch 141
# -------------------------------
# loss: 0.145319  [    0/ 3788]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.131931
#
# Epoch 142
# -------------------------------
# loss: 0.140872  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.129761
#
# Epoch 143
# -------------------------------
# loss: 0.145615  [    0/ 3788]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.128397
#
# Epoch 144
# -------------------------------
# loss: 0.150035  [    0/ 3788]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.129109
#
# Epoch 145
# -------------------------------
# loss: 0.139735  [    0/ 3788]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.130620
#
# Epoch 146
# -------------------------------
# loss: 0.147370  [    0/ 3788]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.130842
#
# Epoch 147
# -------------------------------
# loss: 0.145084  [    0/ 3788]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.128771
#
# Epoch 148
# -------------------------------
# loss: 0.141564  [    0/ 3788]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.127261
#
# Epoch 149
# -------------------------------
# loss: 0.139087  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.127345
#
# Epoch 150
# -------------------------------
# loss: 0.139811  [    0/ 3788]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.125687
#
# Epoch 151
# -------------------------------
# loss: 0.142952  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.124613
#
# Epoch 152
# -------------------------------
# loss: 0.139799  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.124924
#
# Epoch 153
# -------------------------------
# loss: 0.142755  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.122860
#
# Epoch 154
# -------------------------------
# loss: 0.144266  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.120678
#
# Epoch 155
# -------------------------------
# loss: 0.139575  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.119519
#
# Epoch 156
# -------------------------------
# loss: 0.140493  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.118566
#
# Epoch 157
# -------------------------------
# loss: 0.132034  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.117893
#
# Epoch 158
# -------------------------------
# loss: 0.137749  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.117816
#
# Epoch 159
# -------------------------------
# loss: 0.134667  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.117060
#
# Epoch 160
# -------------------------------
# loss: 0.134982  [    0/ 3788]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.115204
#
# Epoch 161
# -------------------------------
# loss: 0.133103  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.114214
#
# Epoch 162
# -------------------------------
# loss: 0.127532  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.113618
#
# Epoch 163
# -------------------------------
# loss: 0.126148  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.113309
#
# Epoch 164
# -------------------------------
# loss: 0.140813  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.113783
#
# Epoch 165
# -------------------------------
# loss: 0.123366  [    0/ 3788]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.114133
#
# Epoch 166
# -------------------------------
# loss: 0.134040  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.112823
#
# Epoch 167
# -------------------------------
# loss: 0.129295  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.111447
#
# Epoch 168
# -------------------------------
# loss: 0.123893  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.110934
#
# Epoch 169
# -------------------------------
# loss: 0.127344  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110977
#
# Epoch 170
# -------------------------------
# loss: 0.129457  [    0/ 3788]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.111357
#
# Epoch 171
# -------------------------------
# loss: 0.123022  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.111149
#
# Epoch 172
# -------------------------------
# loss: 0.130270  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110901
#
# Epoch 173
# -------------------------------
# loss: 0.125359  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110758
#
# Epoch 174
# -------------------------------
# loss: 0.127937  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110551
#
# Epoch 175
# -------------------------------
# loss: 0.127378  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.110553
#
# Epoch 176
# -------------------------------
# loss: 0.120043  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.110367
#
# Epoch 177
# -------------------------------
# loss: 0.121471  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.110781
#
# Epoch 178
# -------------------------------
# loss: 0.118865  [    0/ 3788]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.110575
#
# Epoch 179
# -------------------------------
# loss: 0.118456  [    0/ 3788]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.109309
#
# Epoch 180
# -------------------------------
# loss: 0.123067  [    0/ 3788]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.107181
#
# Epoch 181
# -------------------------------
# loss: 0.119399  [    0/ 3788]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.104614
#
# Epoch 182
# -------------------------------
# loss: 0.116779  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.102609
#
# Epoch 183
# -------------------------------
# loss: 0.118718  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.100619
#
# Epoch 184
# -------------------------------
# loss: 0.119309  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.099606
#
# Epoch 185
# -------------------------------
# loss: 0.116860  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.099222
#
# Epoch 186
# -------------------------------
# loss: 0.117632  [    0/ 3788]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.098914
#
# Epoch 187
# -------------------------------
# loss: 0.122355  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.098385
#
# Epoch 188
# -------------------------------
# loss: 0.119589  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.098170
#
# Epoch 189
# -------------------------------
# loss: 0.115809  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.098223
#
# Epoch 190
# -------------------------------
# loss: 0.113925  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.098137
#
# Epoch 191
# -------------------------------
# loss: 0.120843  [    0/ 3788]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.098735
#
# Epoch 192
# -------------------------------
# loss: 0.120204  [    0/ 3788]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.099397
#
# Epoch 193
# -------------------------------
# loss: 0.115064  [    0/ 3788]
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.099741
#
# Epoch 194
# -------------------------------
# loss: 0.116570  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.099383
#
# Epoch 195
# -------------------------------
# loss: 0.116019  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.098326
#
# Epoch 196
# -------------------------------
# loss: 0.109499  [    0/ 3788]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.097659
#
# Epoch 197
# -------------------------------
# loss: 0.118451  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.097389
#
# Epoch 198
# -------------------------------
# loss: 0.112364  [    0/ 3788]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.097780
#
# Epoch 199
# -------------------------------
# loss: 0.109211  [    0/ 3788]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.098406
#
# Epoch 200
# -------------------------------
# loss: 0.110922  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.097786
#
# Done!

# %%
print("Done!")
import matplotlib.pyplot as plt
# %matplotlib inline
hex_d1 = '#91FF7E'
hex_d2 = '#9DA7FF'

plt.figure()
plt.plot(train_loss, hex_d1, label='train loss')
plt.ylabel('train loss')
plt.xlabel('epoch')
plt.plot(valid_loss, hex_d2, label='valid loss')
plt.ylabel('valid loss')
plt.xlabel('epoch')
plt.legend()

plt.savefig(os.path.join(pic_dir, 'conv2_cnn_128_s100_loss.png'))
plt.show()
# Out:
# Done!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


plt.figure()
plt.plot(accuracy, color = '#A3CEF1', label='accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.savefig(os.path.join(pic_dir, 'conv2_cnn_128_s100_acc.png'))
plt.show()
