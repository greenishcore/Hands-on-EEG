# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import random_split
from torch.optim.lr_scheduler import StepLR

# %%
origin_raw_data_dir = "C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\new_implement\\data\\oriigin_raw_data_slid_window_slice_3000"
model_save ='C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\new_implement\\model'
pic_dir = 'C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\new_implement\\pic'

# %%
class EEG_Dataset(Dataset):
    def __init__(self, data_dir):
        self.data_dir = origin_raw_data_dir
        self.file_list = os.listdir(self.data_dir)

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_name = self.file_list[idx]
        file_path = os.path.join(self.data_dir, file_name)
        data = pd.read_csv(file_path, header=None)
        data = data.values
        data = torch.from_numpy(data)
        label_map = {'lefthand': 0, 'read': 1, 'rest': 2, 'walkbase': 3, 'walkl': 4 ,'walkfocus': 5}
        data_label = label_map[file_name.split('_')[0]]
        return data, data_label

# %%
dataset = EEG_Dataset(origin_raw_data_dir)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=False)

# %%
class EEGNet(nn.Module):
    def __init__(self, num_classes=6):
        super(EEGNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=(1, 4), stride=(1, 2))
        self.bn1 = nn.BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.pool1 = nn.MaxPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout1 = nn.Dropout(p=0.25)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(1, 2), stride=(1, 2))
        self.bn2 = nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.pool2 = nn.MaxPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout2 = nn.Dropout(p=0.25)
        self.fc1 = nn.Linear(48576, 128)
        self.dropout3 = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(128, 6)


    def forward(self, x):
        x = torch.unsqueeze(x, 1)
        #print('x:', x.shape)
        x = self.conv1(x)
        #print('conv1:', x.shape)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.pool1(x)
        x = self.dropout1(x)
        x = self.conv2(x)
        #print('conv2:', x.shape)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.pool2(x)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        #print('flatten:', x.shape)
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %%
X = torch.randn(size=( 1, 33, 3000), dtype=torch.float32)
model = EEGNet()
output = model(X)
print(output.shape)
# Out:
# torch.Size([1, 6])

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.cuda.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
learning_rate = 0.0001
num_epochs = 100
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=30, gamma=0.1)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction error
        pred = model(X.float())
        loss = loss_fn(pred, y)
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
            global train_loss
            train_loss.append(loss)



def test(dataloader, model,loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X.float())
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error:\n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    global valid_loss
    valid_loss.append(test_loss)
    global accuracy
    accuracy.append(correct)

# %%
#torch.cuda.empty_cache()
# model = model = EEG_LSTM(input_size=31000, hidden_size=128, num_layers=2,num_classes=train_class_number).to(device)
model = model.cuda()
train_loss = []
valid_loss = []
accuracy = []
for t in range(num_epochs):
    print(f"Epoch {t + 1}\n-------------------------------")
    model.train(True)
    train(train_loader, model, loss_fn, optimizer)

    model.train(False)
    test(test_loader, model, loss_fn)

    if t > num_epochs-5:
        torch.save(model.state_dict(), os.path.join(model_save,'cnn_3000_100e_'+str(t)+'.pt'))

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.899035  [    0/ 3167]
# Test Error:
#  Accuracy: 66.5%, Avg loss: 1.065960
#
# Epoch 2
# -------------------------------
# loss: 0.782965  [    0/ 3167]
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.802907
#
# Epoch 3
# -------------------------------
# loss: 0.614175  [    0/ 3167]
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.624035
#
# Epoch 4
# -------------------------------
# loss: 0.433158  [    0/ 3167]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.448406
#
# Epoch 5
# -------------------------------
# loss: 0.387838  [    0/ 3167]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.361075
#
# Epoch 6
# -------------------------------
# loss: 0.275187  [    0/ 3167]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.349916
#
# Epoch 7
# -------------------------------
# loss: 0.240576  [    0/ 3167]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.321236
#
# Epoch 8
# -------------------------------
# loss: 0.364447  [    0/ 3167]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.262846
#
# Epoch 9
# -------------------------------
# loss: 0.254898  [    0/ 3167]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.275898
#
# Epoch 10
# -------------------------------
# loss: 0.245401  [    0/ 3167]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.221412
#
# Epoch 11
# -------------------------------
# loss: 0.163772  [    0/ 3167]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.209257
#
# Epoch 12
# -------------------------------
# loss: 0.117728  [    0/ 3167]
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.178653
#
# Epoch 13
# -------------------------------
# loss: 0.206877  [    0/ 3167]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.177786
#
# Epoch 14
# -------------------------------
# loss: 0.182778  [    0/ 3167]
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.174167
#
# Epoch 15
# -------------------------------
# loss: 0.161580  [    0/ 3167]
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.159035
#
# Epoch 16
# -------------------------------
# loss: 0.095796  [    0/ 3167]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.149109
#
# Epoch 17
# -------------------------------
# loss: 0.149794  [    0/ 3167]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.143474
#
# Epoch 18
# -------------------------------
# loss: 0.120511  [    0/ 3167]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.133742
#
# Epoch 19
# -------------------------------
# loss: 0.084516  [    0/ 3167]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.131882
#
# Epoch 20
# -------------------------------
# loss: 0.100352  [    0/ 3167]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.140077
#
# Epoch 21
# -------------------------------
# loss: 0.079671  [    0/ 3167]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.129803
#
# Epoch 22
# -------------------------------
# loss: 0.142170  [    0/ 3167]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.127071
#
# Epoch 23
# -------------------------------
# loss: 0.093741  [    0/ 3167]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.117587
#
# Epoch 24
# -------------------------------
# loss: 0.098049  [    0/ 3167]
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.092691
#
# Epoch 25
# -------------------------------
# loss: 0.070651  [    0/ 3167]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.087211
#
# Epoch 26
# -------------------------------
# loss: 0.054881  [    0/ 3167]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.079351
#
# Epoch 27
# -------------------------------
# loss: 0.062552  [    0/ 3167]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.087261
#
# Epoch 28
# -------------------------------
# loss: 0.032702  [    0/ 3167]
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.067785
#
# Epoch 29
# -------------------------------
# loss: 0.054493  [    0/ 3167]
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.067346
#
# Epoch 30
# -------------------------------
# loss: 0.094089  [    0/ 3167]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.067073
#
# Epoch 31
# -------------------------------
# loss: 0.051610  [    0/ 3167]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.069368
#
# Epoch 32
# -------------------------------
# loss: 0.041371  [    0/ 3167]
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.065020
#
# Epoch 33
# -------------------------------
# loss: 0.062401  [    0/ 3167]
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.063369
#
# Epoch 34
# -------------------------------
# loss: 0.032517  [    0/ 3167]
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.072678
#
# Epoch 35
# -------------------------------
# loss: 0.014835  [    0/ 3167]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.066331
#
# Epoch 36
# -------------------------------
# loss: 0.033349  [    0/ 3167]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.075397
#
# Epoch 37
# -------------------------------
# loss: 0.061844  [    0/ 3167]
# Test Error:
#  Accuracy: 98.1%, Avg loss: 0.061320
#
# Epoch 38
# -------------------------------
# loss: 0.049606  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.045044
#
# Epoch 39
# -------------------------------
# loss: 0.037330  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.041917
#
# Epoch 40
# -------------------------------
# loss: 0.065919  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.040844
#
# Epoch 41
# -------------------------------
# loss: 0.033368  [    0/ 3167]
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.040097
#
# Epoch 42
# -------------------------------
# loss: 0.019895  [    0/ 3167]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.046249
#
# Epoch 43
# -------------------------------
# loss: 0.033780  [    0/ 3167]
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.044590
#
# Epoch 44
# -------------------------------
# loss: 0.028276  [    0/ 3167]
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.055645
#
# Epoch 45
# -------------------------------
# loss: 0.029106  [    0/ 3167]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.037013
#
# Epoch 46
# -------------------------------
# loss: 0.011143  [    0/ 3167]
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.045651
#
# Epoch 47
# -------------------------------
# loss: 0.016068  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.039545
#
# Epoch 48
# -------------------------------
# loss: 0.043058  [    0/ 3167]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.035446
#
# Epoch 49
# -------------------------------
# loss: 0.019112  [    0/ 3167]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.043369
#
# Epoch 50
# -------------------------------
# loss: 0.027498  [    0/ 3167]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.036717
#
# Epoch 51
# -------------------------------
# loss: 0.029783  [    0/ 3167]
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.035634
#
# Epoch 52
# -------------------------------
# loss: 0.009891  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.038841
#
# Epoch 53
# -------------------------------
# loss: 0.020029  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.033461
#
# Epoch 54
# -------------------------------
# loss: 0.021332  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.023072
#
# Epoch 55
# -------------------------------
# loss: 0.035747  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.034756
#
# Epoch 56
# -------------------------------
# loss: 0.023082  [    0/ 3167]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.026427
#
# Epoch 57
# -------------------------------
# loss: 0.018835  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.034378
#
# Epoch 58
# -------------------------------
# loss: 0.026159  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.027723
#
# Epoch 59
# -------------------------------
# loss: 0.017168  [    0/ 3167]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041272
#
# Epoch 60
# -------------------------------
# loss: 0.039133  [    0/ 3167]
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.034856
#
# Epoch 61
# -------------------------------
# loss: 0.011946  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.028098
#
# Epoch 62
# -------------------------------
# loss: 0.024396  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.029698
#
# Epoch 63
# -------------------------------
# loss: 0.024924  [    0/ 3167]
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.043171
#
# Epoch 64
# -------------------------------
# loss: 0.018277  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.034437
#
# Epoch 65
# -------------------------------
# loss: 0.010864  [    0/ 3167]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.040807
#
# Epoch 66
# -------------------------------
# loss: 0.026037  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.035259
#
# Epoch 67
# -------------------------------
# loss: 0.020781  [    0/ 3167]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.023166
#
# Epoch 68
# -------------------------------
# loss: 0.010232  [    0/ 3167]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.035525
#
# Epoch 69
# -------------------------------
# loss: 0.025763  [    0/ 3167]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.022341
#
# Epoch 70
# -------------------------------
# loss: 0.025854  [    0/ 3167]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.026399
#
# Epoch 71
# -------------------------------
# loss: 0.023941  [    0/ 3167]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.024707
#
# Epoch 72
# -------------------------------
# loss: 0.061972  [    0/ 3167]
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.025791
#
# Epoch 73
# -------------------------------
# loss: 0.015702  [    0/ 3167]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.018582
#
# Epoch 74
# -------------------------------
# loss: 0.016641  [    0/ 3167]
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.023976
#
# Epoch 75
# -------------------------------
# loss: 0.014309  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.021126
#
# Epoch 76
# -------------------------------
# loss: 0.016656  [    0/ 3167]
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.018387
#
# Epoch 77
# -------------------------------
# loss: 0.005856  [    0/ 3167]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.024975
#
# Epoch 78
# -------------------------------
# loss: 0.020740  [    0/ 3167]
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.024105
#
# Epoch 79
# -------------------------------
# loss: 0.010612  [    0/ 3167]
# Test Error:
#  Accuracy: 99.9%, Avg loss: 0.014108
#
# Epoch 80
# -------------------------------
# loss: 0.021051  [    0/ 3167]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.016252
#
# Epoch 81
# -------------------------------
# loss: 0.012167  [    0/ 3167]
# Test Error:
#  Accuracy: 99.9%, Avg loss: 0.014212
#
# Epoch 82
# -------------------------------
# loss: 0.019099  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.013527
#
# Epoch 83
# -------------------------------
# loss: 0.005421  [    0/ 3167]
# Test Error:
#  Accuracy: 99.9%, Avg loss: 0.012987
#
# Epoch 84
# -------------------------------
# loss: 0.030907  [    0/ 3167]
# Test Error:
#  Accuracy: 99.9%, Avg loss: 0.014539
#
# Epoch 85
# -------------------------------
# loss: 0.003757  [    0/ 3167]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.024801
#
# Epoch 86
# -------------------------------
# loss: 0.031192  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.014182
#
# Epoch 87
# -------------------------------
# loss: 0.027298  [    0/ 3167]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.015273
#
# Epoch 88
# -------------------------------
# loss: 0.006635  [    0/ 3167]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.023929
#
# Epoch 89
# -------------------------------
# loss: 0.012853  [    0/ 3167]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.013527
#
# Epoch 90
# -------------------------------
# loss: 0.040242  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.017542
#
# Epoch 91
# -------------------------------
# loss: 0.016499  [    0/ 3167]
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.016397
#
# Epoch 92
# -------------------------------
# loss: 0.009904  [    0/ 3167]
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.013975
#
# Epoch 93
# -------------------------------
# loss: 0.012788  [    0/ 3167]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.019724
#
# Epoch 94
# -------------------------------
# loss: 0.014263  [    0/ 3167]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.013114
#
# Epoch 95
# -------------------------------
# loss: 0.020424  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.019273
#
# Epoch 96
# -------------------------------
# loss: 0.007973  [    0/ 3167]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.014792
#
# Epoch 97
# -------------------------------
# loss: 0.004517  [    0/ 3167]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.013199
#
# Epoch 98
# -------------------------------
# loss: 0.003947  [    0/ 3167]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.011422
#
# Epoch 99
# -------------------------------
# loss: 0.015192  [    0/ 3167]
# Test Error:
#  Accuracy: 99.9%, Avg loss: 0.011857
#
# Epoch 100
# -------------------------------
# loss: 0.011570  [    0/ 3167]
# Test Error:
#  Accuracy: 99.9%, Avg loss: 0.009699
#
# Done!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
hex_d1 = '#552a28'
hex_d2 = '#005943'

plt.figure()
plt.plot(train_loss,hex_d1,label='train loss')
plt.ylabel('train loss')
plt.xlabel('epoch')
plt.plot(valid_loss,hex_d2,label='valid loss')
plt.ylabel('valid loss')
plt.xlabel('epoch')
plt.legend()

plt.savefig(os.path.join(pic_dir,'cnn_3000_100e_loss_6.png'))
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
hex_d1 = '#552a28'
hex_d2 = '#005943'

plt.figure()
plt.plot(train_loss,hex_d1,label='train loss')
plt.ylabel('train loss')
plt.xlabel('epoch')
plt.plot(valid_loss,hex_d2,label='valid loss')
plt.ylabel('valid loss')
plt.xlabel('epoch')
plt.legend()

plt.savefig(os.path.join(pic_dir,'cnn_3000_100e_loss_6.png'))
plt.show()

# %%
train_loss.to_csv(train_loss.csv)
valid_loss.to_csv(valid_loss.csv)
accuracy.to_csv(accuracy.csv)
