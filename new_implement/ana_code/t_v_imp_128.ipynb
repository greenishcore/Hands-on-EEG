# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import random_split
from torch.optim.lr_scheduler import StepLR

# %%
origin_raw_data_dir = "C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\new_implement\\data\\128"
model_save ='C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\new_implement\\model'
pic_dir = 'C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\new_implement\\pic'

# %%
class EEG_Dataset(Dataset):
    def __init__(self, data_dir):
        self.data_dir = origin_raw_data_dir
        self.file_list = os.listdir(self.data_dir)

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_name = self.file_list[idx]
        file_path = os.path.join(self.data_dir, file_name)
        data = pd.read_csv(file_path, header=None)
        data = data.values
        data = torch.from_numpy(data)
        label_map = {'lefthand': 0, 'read': 1, 'rest': 2, 'walkbase': 3, 'walkl': 4 ,'walkfocus': 5}
        data_label = label_map[file_name.split('_')[0]]
        return data, data_label

# %%
dataset = EEG_Dataset(origin_raw_data_dir)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=4096, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=4096, shuffle=False)

# %%
class EEGNet(nn.Module):
    def __init__(self, num_classes=6):
        super(EEGNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=(1, 4), stride=(1, 2))
        self.bn1 = nn.BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.pool1 = nn.MaxPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout1 = nn.Dropout(p=0.25)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(1, 2), stride=(1, 2))
        self.bn2 = nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.pool2 = nn.MaxPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout2 = nn.Dropout(p=0.25)
        self.fc1 = nn.Linear(1056, 128)
        self.dropout3 = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(128, 6)


    def forward(self, x):
        x = torch.unsqueeze(x, 1)
        #print('x:', x.shape)
        x = self.conv1(x)
        #print('conv1:', x.shape)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.pool1(x)
        x = self.dropout1(x)
        x = self.conv2(x)
        #print('conv2:', x.shape)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.pool2(x)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        #print('flatten:', x.shape)
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %%
X = torch.randn(size=( 1, 33, 128), dtype=torch.float32)
model = EEGNet()
output = model(X)
print(output.shape)
# Out:
# torch.Size([1, 6])

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.cuda.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
learning_rate = 0.001
num_epochs = 100
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=30, gamma=0.1)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction error
        pred = model(X.float())
        loss = loss_fn(pred, y)
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
            global train_loss
            train_loss.append(loss)



def test(dataloader, model,loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X.float())
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error:\n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    global valid_loss
    valid_loss.append(test_loss)
    global accuracy
    accuracy.append(correct)

# %%
#torch.cuda.empty_cache()
# model = model = EEG_LSTM(input_size=31000, hidden_size=128, num_layers=2,num_classes=train_class_number).to(device)
model = model.cuda()
train_loss = []
valid_loss = []
accuracy = []
for t in range(num_epochs):
    print(f"Epoch {t + 1}\n-------------------------------")
    model.train(True)
    train(train_loader, model, loss_fn, optimizer)

    model.train(False)
    test(test_loader, model, loss_fn)

    if t > num_epochs-5:
        torch.save(model.state_dict(), os.path.join(model_save,'cnn_128_100e_'+str(t)+'.pt'))

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.012944  [    0/ 3788]
# Test Error:
#  Accuracy: 13.5%, Avg loss: 1.830493
#
# Epoch 2
# -------------------------------
# loss: 1.793654  [    0/ 3788]
# Test Error:
#  Accuracy: 22.8%, Avg loss: 1.738636
#
# Epoch 3
# -------------------------------
# loss: 1.681231  [    0/ 3788]
# Test Error:
#  Accuracy: 31.9%, Avg loss: 1.691991
#
# Epoch 4
# -------------------------------
# loss: 1.625078  [    0/ 3788]
# Test Error:
#  Accuracy: 32.5%, Avg loss: 1.659886
#
# Epoch 5
# -------------------------------
# loss: 1.607784  [    0/ 3788]
# Test Error:
#  Accuracy: 35.6%, Avg loss: 1.634987
#
# Epoch 6
# -------------------------------
# loss: 1.584392  [    0/ 3788]
# Test Error:
#  Accuracy: 43.5%, Avg loss: 1.614790
#
# Epoch 7
# -------------------------------
# loss: 1.558861  [    0/ 3788]
# Test Error:
#  Accuracy: 52.3%, Avg loss: 1.598101
#
# Epoch 8
# -------------------------------
# loss: 1.528654  [    0/ 3788]
# Test Error:
#  Accuracy: 53.6%, Avg loss: 1.583133
#
# Epoch 9
# -------------------------------
# loss: 1.504744  [    0/ 3788]
# Test Error:
#  Accuracy: 54.2%, Avg loss: 1.569040
#
# Epoch 10
# -------------------------------
# loss: 1.467994  [    0/ 3788]
# Test Error:
#  Accuracy: 54.8%, Avg loss: 1.554950
#
# Epoch 11
# -------------------------------
# loss: 1.440459  [    0/ 3788]
# Test Error:
#  Accuracy: 54.6%, Avg loss: 1.540127
#
# Epoch 12
# -------------------------------
# loss: 1.401604  [    0/ 3788]
# Test Error:
#  Accuracy: 53.9%, Avg loss: 1.522528
#
# Epoch 13
# -------------------------------
# loss: 1.368174  [    0/ 3788]
# Test Error:
#  Accuracy: 52.9%, Avg loss: 1.504896
#
# Epoch 14
# -------------------------------
# loss: 1.326253  [    0/ 3788]
# Test Error:
#  Accuracy: 52.7%, Avg loss: 1.487128
#
# Epoch 15
# -------------------------------
# loss: 1.293183  [    0/ 3788]
# Test Error:
#  Accuracy: 52.8%, Avg loss: 1.468934
#
# Epoch 16
# -------------------------------
# loss: 1.254594  [    0/ 3788]
# Test Error:
#  Accuracy: 53.0%, Avg loss: 1.450704
#
# Epoch 17
# -------------------------------
# loss: 1.226483  [    0/ 3788]
# Test Error:
#  Accuracy: 51.6%, Avg loss: 1.432399
#
# Epoch 18
# -------------------------------
# loss: 1.180557  [    0/ 3788]
# Test Error:
#  Accuracy: 50.8%, Avg loss: 1.414198
#
# Epoch 19
# -------------------------------
# loss: 1.148447  [    0/ 3788]
# Test Error:
#  Accuracy: 50.4%, Avg loss: 1.396065
#
# Epoch 20
# -------------------------------
# loss: 1.112034  [    0/ 3788]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 1.379512
#
# Epoch 21
# -------------------------------
# loss: 1.083631  [    0/ 3788]
# Test Error:
#  Accuracy: 49.8%, Avg loss: 1.368004
#
# Epoch 22
# -------------------------------
# loss: 1.060221  [    0/ 3788]
# Test Error:
#  Accuracy: 49.9%, Avg loss: 1.365042
#
# Epoch 23
# -------------------------------
# loss: 1.019844  [    0/ 3788]
# Test Error:
#  Accuracy: 50.1%, Avg loss: 1.374131
#
# Epoch 24
# -------------------------------
# loss: 0.999968  [    0/ 3788]
# Test Error:
#  Accuracy: 48.8%, Avg loss: 1.392787
#
# Epoch 25
# -------------------------------
# loss: 0.985696  [    0/ 3788]
# Test Error:
#  Accuracy: 46.1%, Avg loss: 1.412138
#
# Epoch 26
# -------------------------------
# loss: 0.952991  [    0/ 3788]
# Test Error:
#  Accuracy: 43.0%, Avg loss: 1.432379
#
# Epoch 27
# -------------------------------
# loss: 0.941254  [    0/ 3788]
# Test Error:
#  Accuracy: 41.5%, Avg loss: 1.454445
#
# Epoch 28
# -------------------------------
# loss: 0.902992  [    0/ 3788]
# Test Error:
#  Accuracy: 40.7%, Avg loss: 1.464544
#
# Epoch 29
# -------------------------------
# loss: 0.888785  [    0/ 3788]
# Test Error:
#  Accuracy: 40.0%, Avg loss: 1.473505
#
# Epoch 30
# -------------------------------
# loss: 0.867761  [    0/ 3788]
# Test Error:
#  Accuracy: 40.0%, Avg loss: 1.495406
#
# Epoch 31
# -------------------------------
# loss: 0.859400  [    0/ 3788]
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.522580
#
# Epoch 32
# -------------------------------
# loss: 0.821818  [    0/ 3788]
# Test Error:
#  Accuracy: 39.8%, Avg loss: 1.542903
#
# Epoch 33
# -------------------------------
# loss: 0.812041  [    0/ 3788]
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.555580
#
# Epoch 34
# -------------------------------
# loss: 0.791257  [    0/ 3788]
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.572929
#
# Epoch 35
# -------------------------------
# loss: 0.774315  [    0/ 3788]
# Test Error:
#  Accuracy: 38.4%, Avg loss: 1.604556
#
# Epoch 36
# -------------------------------
# loss: 0.767302  [    0/ 3788]
# Test Error:
#  Accuracy: 38.1%, Avg loss: 1.633764
#
# Epoch 37
# -------------------------------
# loss: 0.758142  [    0/ 3788]
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.645240
#
# Epoch 38
# -------------------------------
# loss: 0.753294  [    0/ 3788]
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.631041
#
# Epoch 39
# -------------------------------
# loss: 0.722651  [    0/ 3788]
# Test Error:
#  Accuracy: 41.4%, Avg loss: 1.603108
#
# Epoch 40
# -------------------------------
# loss: 0.709346  [    0/ 3788]
# Test Error:
#  Accuracy: 43.1%, Avg loss: 1.571247
#
# Epoch 41
# -------------------------------
# loss: 0.691155  [    0/ 3788]
# Test Error:
#  Accuracy: 45.5%, Avg loss: 1.532201
#
# Epoch 42
# -------------------------------
# loss: 0.687752  [    0/ 3788]
# Test Error:
#  Accuracy: 47.9%, Avg loss: 1.490190
#
# Epoch 43
# -------------------------------
# loss: 0.675008  [    0/ 3788]
# Test Error:
#  Accuracy: 49.1%, Avg loss: 1.439749
#
# Epoch 44
# -------------------------------
# loss: 0.656825  [    0/ 3788]
# Test Error:
#  Accuracy: 50.5%, Avg loss: 1.387566
#
# Epoch 45
# -------------------------------
# loss: 0.645015  [    0/ 3788]
# Test Error:
#  Accuracy: 52.4%, Avg loss: 1.336493
#
# Epoch 46
# -------------------------------
# loss: 0.638025  [    0/ 3788]
# Test Error:
#  Accuracy: 54.7%, Avg loss: 1.283648
#
# Epoch 47
# -------------------------------
# loss: 0.620784  [    0/ 3788]
# Test Error:
#  Accuracy: 55.9%, Avg loss: 1.221845
#
# Epoch 48
# -------------------------------
# loss: 0.603791  [    0/ 3788]
# Test Error:
#  Accuracy: 57.2%, Avg loss: 1.162859
#
# Epoch 49
# -------------------------------
# loss: 0.600124  [    0/ 3788]
# Test Error:
#  Accuracy: 59.5%, Avg loss: 1.119843
#
# Epoch 50
# -------------------------------
# loss: 0.589097  [    0/ 3788]
# Test Error:
#  Accuracy: 61.0%, Avg loss: 1.085212
#
# Epoch 51
# -------------------------------
# loss: 0.575969  [    0/ 3788]
# Test Error:
#  Accuracy: 62.8%, Avg loss: 1.046518
#
# Epoch 52
# -------------------------------
# loss: 0.563846  [    0/ 3788]
# Test Error:
#  Accuracy: 64.6%, Avg loss: 0.996943
#
# Epoch 53
# -------------------------------
# loss: 0.559996  [    0/ 3788]
# Test Error:
#  Accuracy: 66.4%, Avg loss: 0.948241
#
# Epoch 54
# -------------------------------
# loss: 0.563137  [    0/ 3788]
# Test Error:
#  Accuracy: 67.2%, Avg loss: 0.908961
#
# Epoch 55
# -------------------------------
# loss: 0.551472  [    0/ 3788]
# Test Error:
#  Accuracy: 68.1%, Avg loss: 0.874049
#
# Epoch 56
# -------------------------------
# loss: 0.541197  [    0/ 3788]
# Test Error:
#  Accuracy: 70.5%, Avg loss: 0.844142
#
# Epoch 57
# -------------------------------
# loss: 0.529825  [    0/ 3788]
# Test Error:
#  Accuracy: 71.9%, Avg loss: 0.810660
#
# Epoch 58
# -------------------------------
# loss: 0.516961  [    0/ 3788]
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.771265
#
# Epoch 59
# -------------------------------
# loss: 0.514517  [    0/ 3788]
# Test Error:
#  Accuracy: 74.8%, Avg loss: 0.732307
#
# Epoch 60
# -------------------------------
# loss: 0.501290  [    0/ 3788]
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.698782
#
# Epoch 61
# -------------------------------
# loss: 0.496724  [    0/ 3788]
# Test Error:
#  Accuracy: 76.8%, Avg loss: 0.675334
#
# Epoch 62
# -------------------------------
# loss: 0.490707  [    0/ 3788]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.651639
#
# Epoch 63
# -------------------------------
# loss: 0.488847  [    0/ 3788]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.625846
#
# Epoch 64
# -------------------------------
# loss: 0.478308  [    0/ 3788]
# Test Error:
#  Accuracy: 79.3%, Avg loss: 0.602600
#
# Epoch 65
# -------------------------------
# loss: 0.465171  [    0/ 3788]
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.581023
#
# Epoch 66
# -------------------------------
# loss: 0.474978  [    0/ 3788]
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.561348
#
# Epoch 67
# -------------------------------
# loss: 0.465836  [    0/ 3788]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.540368
#
# Epoch 68
# -------------------------------
# loss: 0.452327  [    0/ 3788]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.521077
#
# Epoch 69
# -------------------------------
# loss: 0.446953  [    0/ 3788]
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.502396
#
# Epoch 70
# -------------------------------
# loss: 0.440404  [    0/ 3788]
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.486458
#
# Epoch 71
# -------------------------------
# loss: 0.439919  [    0/ 3788]
# Test Error:
#  Accuracy: 83.6%, Avg loss: 0.475491
#
# Epoch 72
# -------------------------------
# loss: 0.440385  [    0/ 3788]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.466354
#
# Epoch 73
# -------------------------------
# loss: 0.429791  [    0/ 3788]
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.458942
#
# Epoch 74
# -------------------------------
# loss: 0.435952  [    0/ 3788]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.452535
#
# Epoch 75
# -------------------------------
# loss: 0.422160  [    0/ 3788]
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.443662
#
# Epoch 76
# -------------------------------
# loss: 0.412081  [    0/ 3788]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.433352
#
# Epoch 77
# -------------------------------
# loss: 0.407365  [    0/ 3788]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.425086
#
# Epoch 78
# -------------------------------
# loss: 0.406246  [    0/ 3788]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.415966
#
# Epoch 79
# -------------------------------
# loss: 0.402476  [    0/ 3788]
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.409121
#
# Epoch 80
# -------------------------------
# loss: 0.398050  [    0/ 3788]
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.401964
#
# Epoch 81
# -------------------------------
# loss: 0.396294  [    0/ 3788]
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.395766
#
# Epoch 82
# -------------------------------
# loss: 0.388955  [    0/ 3788]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.390856
#
# Epoch 83
# -------------------------------
# loss: 0.392867  [    0/ 3788]
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.386600
#
# Epoch 84
# -------------------------------
# loss: 0.386542  [    0/ 3788]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.382743
#
# Epoch 85
# -------------------------------
# loss: 0.376701  [    0/ 3788]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.378371
#
# Epoch 86
# -------------------------------
# loss: 0.373920  [    0/ 3788]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.373407
#
# Epoch 87
# -------------------------------
# loss: 0.377373  [    0/ 3788]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.367258
#
# Epoch 88
# -------------------------------
# loss: 0.367444  [    0/ 3788]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.362431
#
# Epoch 89
# -------------------------------
# loss: 0.372576  [    0/ 3788]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.359149
#
# Epoch 90
# -------------------------------
# loss: 0.369795  [    0/ 3788]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.356688
#
# Epoch 91
# -------------------------------
# loss: 0.366299  [    0/ 3788]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.354522
#
# Epoch 92
# -------------------------------
# loss: 0.353310  [    0/ 3788]
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.351963
#
# Epoch 93
# -------------------------------
# loss: 0.344275  [    0/ 3788]
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.347596
#
# Epoch 94
# -------------------------------
# loss: 0.358653  [    0/ 3788]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.343410
#
# Epoch 95
# -------------------------------
# loss: 0.358550  [    0/ 3788]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.338112
#
# Epoch 96
# -------------------------------
# loss: 0.344876  [    0/ 3788]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.333680
#
# Epoch 97
# -------------------------------
# loss: 0.346799  [    0/ 3788]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.330256
#
# Epoch 98
# -------------------------------
# loss: 0.345942  [    0/ 3788]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.327636
#
# Epoch 99
# -------------------------------
# loss: 0.343420  [    0/ 3788]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.326013
#
# Epoch 100
# -------------------------------
# loss: 0.354920  [    0/ 3788]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.324337
#
# Done!

# %%
print("Done!")
import matplotlib.pyplot as plt
# %matplotlib inline
hex_d1 = '#552a28'
hex_d2 = '#005943'

plt.figure()
plt.plot(train_loss, hex_d1, label='train loss')
plt.ylabel('train loss')
plt.xlabel('epoch')
plt.plot(valid_loss, hex_d2, label='valid loss')
plt.ylabel('valid loss')
plt.xlabel('epoch')
plt.legend()

plt.savefig(os.path.join(pic_dir, 'cnn_3000_100e_loss_6.png'))
plt.show()
# Out:
# Done!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


plt.figure()
plt.plot(accuracy, color = '#550300', label='accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.savefig('cnn_3000_100e_accuracy_2.png')
plt.show()
