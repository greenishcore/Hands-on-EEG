# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
origin_raw_data_dir = 'C:\\Users\\a1882\\Desktop\\EEG\\normal\\data\\1000_s100'
model_save ='C:\\Users\\a1882\\Desktop\\EEG\\normal\\model'
pic_dir = 'C:\\Users\\a1882\\Desktop\\EEG\\normal\\pic'

# %%
train_loss = pd.read_csv("C:\\Users\\a1882\\Desktop\\EEG\\normal\\pic\\cnn_conv3_1000_s100_tloss.csv",header = None)
valid_loss = pd.read_csv("C:\\Users\\a1882\\Desktop\\EEG\\normal\\pic\\cnn_conv3_1000_s100__vloss.csv",header = None)
accuracy = pd.read_csv("C:\\Users\\a1882\\Desktop\\EEG\\normal\\pic\\cnn_conv3_1000_s100__acc.csv",header = None)
print(train_loss)
print(valid_loss)
# Out:
#          0         1
# 0      NaN  0.000000
# 1      0.0  1.051166
# 2      1.0  0.877213
# 3      2.0  0.674027
# 4      3.0  0.167478
# ..     ...       ...
# 296  295.0  0.531183
# 297  296.0  0.000138
# 298  297.0  0.000335
# 299  298.0  0.081026
# 300  299.0  0.036041
#
# [301 rows x 2 columns]
#        0         1
# 0    NaN  0.000000
# 1    0.0  2.256113
# 2    1.0  0.391391
# 3    2.0  0.558411
# 4    3.0  0.770773
# ..   ...       ...
# 56  55.0  0.260938
# 57  56.0  0.010477
# 58  57.0  0.101889
# 59  58.0  0.065841
# 60  59.0  0.160269
#
# [61 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
hex_d1 = '#552a28'
hex_d2 = '#005943'

plt.figure()
plt.plot(train_loss.iloc[1:60,1], hex_d1, label='train loss')
plt.ylabel('train loss')
plt.xlabel('epoch')
plt.plot(valid_loss.iloc[1:,1], hex_d2, label='valid loss')
plt.ylabel('valid loss')
plt.xlabel('epoch')
plt.legend()

plt.savefig(os.path.join(pic_dir, 'cnn3_1000_100e_loss.png'))
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


plt.figure()
plt.plot(accuracy.iloc[1:60,1], color = '#550300', label='accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.savefig(os.path.join(pic_dir,'cnn3_1000_100e_accuracy.png'))
plt.show()
