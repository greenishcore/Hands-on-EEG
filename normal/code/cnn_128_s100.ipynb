# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import random_split
from torch.optim.lr_scheduler import StepLR

# %%
origin_raw_data_dir = 'C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\normal\\data\\128_s100'
model_save ='C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\normal\\model'
pic_dir = 'C:\\Users\\14870\\PycharmProjects\\Hands-on-EEG\\normal\\pic'

# %%
class EEG_Dataset(Dataset):
    def __init__(self, data_dir):
        self.data_dir = origin_raw_data_dir
        self.file_list = os.listdir(self.data_dir)

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_name = self.file_list[idx]
        file_path = os.path.join(self.data_dir, file_name)
        data = pd.read_csv(file_path, header=None)
        data = data.values
        data = torch.from_numpy(data)
        label_map = {'lefthand': 0, 'read': 1, 'rest': 2, 'walkbase': 3, 'walkl': 4 ,'walkfocus': 5}
        data_label = label_map[file_name.split('_')[0]]
        return data, data_label

# %%
dataset = EEG_Dataset(origin_raw_data_dir)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=4096, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=4096, shuffle=False)

# %%
class EEGNet(nn.Module):
    def __init__(self, num_classes=6):
        super(EEGNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=(1, 4), stride=(1, 2))
        self.bn1 = nn.BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.pool1 = nn.MaxPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout1 = nn.Dropout(p=0.25)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(1, 2), stride=(1, 2))
        self.bn2 = nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.pool2 = nn.MaxPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout2 = nn.Dropout(p=0.25)
        self.fc1 = nn.Linear(1024, 128)
        self.dropout3 = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(128, 6)


    def forward(self, x):
        x = torch.unsqueeze(x, 1)
        # print('x:', x.shape)
        x = self.conv1(x)
        # print('conv1:', x.shape)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.pool1(x)
        # print('pool1:', x.shape)
        x = self.dropout1(x)
        x = self.conv2(x)
        # print('conv2:', x.shape)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.pool2(x)
        # print('pool2:', x.shape)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        # print('flatten:', x.shape)
        x = self.fc1(x)
        # print('fc1:', x.shape)
        x = torch.relu(x)
        x = self.dropout3(x)
        x = self.fc2(x)
        # print('fc2:', x.shape)
        return x

# %%
X = torch.randn(size=( 1, 32, 128), dtype=torch.float32)
model = EEGNet()
output = model(X)
print(output.shape)
# Out:
# torch.Size([1, 6])

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.cuda.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
learning_rate = 0.001
num_epochs = 200
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=50, gamma=0.1)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction error
        pred = model(X.float())
        loss = loss_fn(pred, y)
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
            global train_loss
            train_loss.append(loss)



def test(dataloader, model,loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X.float())
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error:\n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    global valid_loss
    valid_loss.append(test_loss)
    global accuracy
    accuracy.append(correct)

# %%
#torch.cuda.empty_cache()
# model = model = EEG_LSTM(input_size=31000, hidden_size=128, num_layers=2,num_classes=train_class_number).to(device)
model = model.cuda()
train_loss = []
valid_loss = []
accuracy = []
for t in range(num_epochs):
    print(f"Epoch {t + 1}\n-------------------------------")
    model.train(True)
    train(train_loader, model, loss_fn, optimizer)

    model.train(False)
    test(test_loader, model, loss_fn)

    if t > num_epochs-5:
        torch.save(model.state_dict(), os.path.join(model_save,'cnn_128_100e_'+str(t)+'.pt'))

print("Done!")
train_loss=pd.DataFrame(train_loss)
valid_loss=pd.DataFrame(valid_loss)
accuracy=pd.DataFrame(accuracy)

train_loss.to_csv(os.path.join(pic_dir,'cnn_128_s100_tloss.csv'))
valid_loss.to_csv(os.path.join(pic_dir,'cnn_128_s100_vloss.csv'))
accuracy.to_csv(os.path.join(pic_dir,'cnn_128_s100_acc.csv'))
# Out:
# Epoch 1
# -------------------------------
# loss: 1.800900  [    0/ 3788]
# Test Error:
#  Accuracy: 22.6%, Avg loss: 1.616932
#
# Epoch 2
# -------------------------------
# loss: 1.617377  [    0/ 3788]
# Test Error:
#  Accuracy: 23.2%, Avg loss: 1.522671
#
# Epoch 3
# -------------------------------
# loss: 1.522937  [    0/ 3788]
# Test Error:
#  Accuracy: 31.7%, Avg loss: 1.487916
#
# Epoch 4
# -------------------------------
# loss: 1.404660  [    0/ 3788]
# Test Error:
#  Accuracy: 53.5%, Avg loss: 1.446387
#
# Epoch 5
# -------------------------------
# loss: 1.312750  [    0/ 3788]
# Test Error:
#  Accuracy: 65.2%, Avg loss: 1.390085
#
# Epoch 6
# -------------------------------
# loss: 1.225238  [    0/ 3788]
# Test Error:
#  Accuracy: 69.5%, Avg loss: 1.339224
#
# Epoch 7
# -------------------------------
# loss: 1.128020  [    0/ 3788]
# Test Error:
#  Accuracy: 70.4%, Avg loss: 1.292038
#
# Epoch 8
# -------------------------------
# loss: 1.072558  [    0/ 3788]
# Test Error:
#  Accuracy: 71.4%, Avg loss: 1.240140
#
# Epoch 9
# -------------------------------
# loss: 0.996256  [    0/ 3788]
# Test Error:
#  Accuracy: 71.6%, Avg loss: 1.183318
#
# Epoch 10
# -------------------------------
# loss: 0.946382  [    0/ 3788]
# Test Error:
#  Accuracy: 72.2%, Avg loss: 1.120408
#
# Epoch 11
# -------------------------------
# loss: 0.890837  [    0/ 3788]
# Test Error:
#  Accuracy: 73.8%, Avg loss: 1.062580
#
# Epoch 12
# -------------------------------
# loss: 0.855088  [    0/ 3788]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 1.007957
#
# Epoch 13
# -------------------------------
# loss: 0.809009  [    0/ 3788]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.956367
#
# Epoch 14
# -------------------------------
# loss: 0.778772  [    0/ 3788]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.909961
#
# Epoch 15
# -------------------------------
# loss: 0.742005  [    0/ 3788]
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.865371
#
# Epoch 16
# -------------------------------
# loss: 0.726044  [    0/ 3788]
# Test Error:
#  Accuracy: 76.1%, Avg loss: 0.822451
#
# Epoch 17
# -------------------------------
# loss: 0.699070  [    0/ 3788]
# Test Error:
#  Accuracy: 76.9%, Avg loss: 0.784707
#
# Epoch 18
# -------------------------------
# loss: 0.667154  [    0/ 3788]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.752764
#
# Epoch 19
# -------------------------------
# loss: 0.644955  [    0/ 3788]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.723694
#
# Epoch 20
# -------------------------------
# loss: 0.623273  [    0/ 3788]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.693188
#
# Epoch 21
# -------------------------------
# loss: 0.606535  [    0/ 3788]
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.664393
#
# Epoch 22
# -------------------------------
# loss: 0.599808  [    0/ 3788]
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.636907
#
# Epoch 23
# -------------------------------
# loss: 0.560361  [    0/ 3788]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.613693
#
# Epoch 24
# -------------------------------
# loss: 0.565907  [    0/ 3788]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.593468
#
# Epoch 25
# -------------------------------
# loss: 0.553579  [    0/ 3788]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.573972
#
# Epoch 26
# -------------------------------
# loss: 0.537897  [    0/ 3788]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.554429
#
# Epoch 27
# -------------------------------
# loss: 0.523262  [    0/ 3788]
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.536705
#
# Epoch 28
# -------------------------------
# loss: 0.518400  [    0/ 3788]
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.520947
#
# Epoch 29
# -------------------------------
# loss: 0.496501  [    0/ 3788]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.507168
#
# Epoch 30
# -------------------------------
# loss: 0.494279  [    0/ 3788]
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.495344
#
# Epoch 31
# -------------------------------
# loss: 0.484759  [    0/ 3788]
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.485002
#
# Epoch 32
# -------------------------------
# loss: 0.461196  [    0/ 3788]
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.475189
#
# Epoch 33
# -------------------------------
# loss: 0.448707  [    0/ 3788]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.465436
#
# Epoch 34
# -------------------------------
# loss: 0.446774  [    0/ 3788]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.455746
#
# Epoch 35
# -------------------------------
# loss: 0.449228  [    0/ 3788]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.446974
#
# Epoch 36
# -------------------------------
# loss: 0.429146  [    0/ 3788]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.439481
#
# Epoch 37
# -------------------------------
# loss: 0.420433  [    0/ 3788]
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.432524
#
# Epoch 38
# -------------------------------
# loss: 0.411511  [    0/ 3788]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.426194
#
# Epoch 39
# -------------------------------
# loss: 0.402769  [    0/ 3788]
# Test Error:
#  Accuracy: 86.3%, Avg loss: 0.420268
#
# Epoch 40
# -------------------------------
# loss: 0.393205  [    0/ 3788]
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.413272
#
# Epoch 41
# -------------------------------
# loss: 0.389634  [    0/ 3788]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.406364
#
# Epoch 42
# -------------------------------
# loss: 0.386238  [    0/ 3788]
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.400756
#
# Epoch 43
# -------------------------------
# loss: 0.384778  [    0/ 3788]
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.397271
#
# Epoch 44
# -------------------------------
# loss: 0.372400  [    0/ 3788]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.394954
#
# Epoch 45
# -------------------------------
# loss: 0.369344  [    0/ 3788]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.393748
#
# Epoch 46
# -------------------------------
# loss: 0.357803  [    0/ 3788]
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.388664
#
# Epoch 47
# -------------------------------
# loss: 0.352355  [    0/ 3788]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.382340
#
# Epoch 48
# -------------------------------
# loss: 0.338017  [    0/ 3788]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.375157
#
# Epoch 49
# -------------------------------
# loss: 0.343423  [    0/ 3788]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.367842
#
# Epoch 50
# -------------------------------
# loss: 0.328314  [    0/ 3788]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.361308
#
# Epoch 51
# -------------------------------
# loss: 0.324437  [    0/ 3788]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.355288
#
# Epoch 52
# -------------------------------
# loss: 0.324282  [    0/ 3788]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.348611
#
# Epoch 53
# -------------------------------
# loss: 0.321675  [    0/ 3788]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.342165
#
# Epoch 54
# -------------------------------
# loss: 0.313785  [    0/ 3788]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.336100
#
# Epoch 55
# -------------------------------
# loss: 0.313582  [    0/ 3788]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.331376
#
# Epoch 56
# -------------------------------
# loss: 0.311783  [    0/ 3788]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.326747
#
# Epoch 57
# -------------------------------
# loss: 0.297756  [    0/ 3788]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.322639
#
# Epoch 58
# -------------------------------
# loss: 0.290486  [    0/ 3788]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.318417
#
# Epoch 59
# -------------------------------
# loss: 0.290097  [    0/ 3788]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.315475
#
# Epoch 60
# -------------------------------
# loss: 0.299080  [    0/ 3788]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.313912
#
# Epoch 61
# -------------------------------
# loss: 0.283651  [    0/ 3788]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.311941
#
# Epoch 62
# -------------------------------
# loss: 0.291281  [    0/ 3788]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.308895
#
# Epoch 63
# -------------------------------
# loss: 0.276948  [    0/ 3788]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.305936
#
# Epoch 64
# -------------------------------
# loss: 0.282805  [    0/ 3788]
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.301747
#
# Epoch 65
# -------------------------------
# loss: 0.273323  [    0/ 3788]
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.296759
#
# Epoch 66
# -------------------------------
# loss: 0.265099  [    0/ 3788]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.290559
#
# Epoch 67
# -------------------------------
# loss: 0.267951  [    0/ 3788]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.284635
#
# Epoch 68
# -------------------------------
# loss: 0.262826  [    0/ 3788]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.278533
#
# Epoch 69
# -------------------------------
# loss: 0.263180  [    0/ 3788]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.272573
#
# Epoch 70
# -------------------------------
# loss: 0.262548  [    0/ 3788]
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.266694
#
# Epoch 71
# -------------------------------
# loss: 0.256396  [    0/ 3788]
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.261253
#
# Epoch 72
# -------------------------------
# loss: 0.256298  [    0/ 3788]
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.255433
#
# Epoch 73
# -------------------------------
# loss: 0.252389  [    0/ 3788]
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.250790
#
# Epoch 74
# -------------------------------
# loss: 0.252987  [    0/ 3788]
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.246780
#
# Epoch 75
# -------------------------------
# loss: 0.250202  [    0/ 3788]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.244514
#
# Epoch 76
# -------------------------------
# loss: 0.253724  [    0/ 3788]
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.244187
#
# Epoch 77
# -------------------------------
# loss: 0.242890  [    0/ 3788]
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.244313
#
# Epoch 78
# -------------------------------
# loss: 0.239143  [    0/ 3788]
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.242481
#
# Epoch 79
# -------------------------------
# loss: 0.234394  [    0/ 3788]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.238937
#
# Epoch 80
# -------------------------------
# loss: 0.238889  [    0/ 3788]
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.234714
#
# Epoch 81
# -------------------------------
# loss: 0.233174  [    0/ 3788]
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.227993
#
# Epoch 82
# -------------------------------
# loss: 0.231240  [    0/ 3788]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.223076
#
# Epoch 83
# -------------------------------
# loss: 0.239332  [    0/ 3788]
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.218235
#
# Epoch 84
# -------------------------------
# loss: 0.223509  [    0/ 3788]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.214225
#
# Epoch 85
# -------------------------------
# loss: 0.231328  [    0/ 3788]
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.210647
#
# Epoch 86
# -------------------------------
# loss: 0.225267  [    0/ 3788]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.207998
#
# Epoch 87
# -------------------------------
# loss: 0.219046  [    0/ 3788]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.205084
#
# Epoch 88
# -------------------------------
# loss: 0.222008  [    0/ 3788]
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.201950
#
# Epoch 89
# -------------------------------
# loss: 0.212310  [    0/ 3788]
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.198259
#
# Epoch 90
# -------------------------------
# loss: 0.206874  [    0/ 3788]
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.195025
#
# Epoch 91
# -------------------------------
# loss: 0.218628  [    0/ 3788]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.192580
#
# Epoch 92
# -------------------------------
# loss: 0.212250  [    0/ 3788]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.190777
#
# Epoch 93
# -------------------------------
# loss: 0.210877  [    0/ 3788]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.189668
#
# Epoch 94
# -------------------------------
# loss: 0.210050  [    0/ 3788]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.188675
#
# Epoch 95
# -------------------------------
# loss: 0.208706  [    0/ 3788]
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.186592
#
# Epoch 96
# -------------------------------
# loss: 0.206005  [    0/ 3788]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.183925
#
# Epoch 97
# -------------------------------
# loss: 0.204607  [    0/ 3788]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.180630
#
# Epoch 98
# -------------------------------
# loss: 0.198633  [    0/ 3788]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.177377
#
# Epoch 99
# -------------------------------
# loss: 0.201370  [    0/ 3788]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.175314
#
# Epoch 100
# -------------------------------
# loss: 0.206153  [    0/ 3788]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.174877
#
# Epoch 101
# -------------------------------
# loss: 0.195947  [    0/ 3788]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.175308
#
# Epoch 102
# -------------------------------
# loss: 0.197133  [    0/ 3788]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.174231
#
# Epoch 103
# -------------------------------
# loss: 0.189907  [    0/ 3788]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.171593
#
# Epoch 104
# -------------------------------
# loss: 0.198903  [    0/ 3788]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.169570
#
# Epoch 105
# -------------------------------
# loss: 0.194916  [    0/ 3788]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.168324
#
# Epoch 106
# -------------------------------
# loss: 0.192203  [    0/ 3788]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.167128
#
# Epoch 107
# -------------------------------
# loss: 0.187744  [    0/ 3788]
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.166305
#
# Epoch 108
# -------------------------------
# loss: 0.195829  [    0/ 3788]
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.166002
#
# Epoch 109
# -------------------------------
# loss: 0.185102  [    0/ 3788]
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.164158
#
# Epoch 110
# -------------------------------
# loss: 0.181107  [    0/ 3788]
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.160854
#
# Epoch 111
# -------------------------------
# loss: 0.181735  [    0/ 3788]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.157123
#
# Epoch 112
# -------------------------------
# loss: 0.180428  [    0/ 3788]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.153875
#
# Epoch 113
# -------------------------------
# loss: 0.180384  [    0/ 3788]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.153674
#
# Epoch 114
# -------------------------------
# loss: 0.175340  [    0/ 3788]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.154956
#
# Epoch 115
# -------------------------------
# loss: 0.182819  [    0/ 3788]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.155685
#
# Epoch 116
# -------------------------------
# loss: 0.173562  [    0/ 3788]
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.154217
#
# Epoch 117
# -------------------------------
# loss: 0.180852  [    0/ 3788]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.150875
#
# Epoch 118
# -------------------------------
# loss: 0.179113  [    0/ 3788]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.148058
#
# Epoch 119
# -------------------------------
# loss: 0.174654  [    0/ 3788]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.146437
#
# Epoch 120
# -------------------------------
# loss: 0.170464  [    0/ 3788]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.146166
#
# Epoch 121
# -------------------------------
# loss: 0.184690  [    0/ 3788]
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.146323
#
# Epoch 122
# -------------------------------
# loss: 0.173182  [    0/ 3788]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.146890
#
# Epoch 123
# -------------------------------
# loss: 0.169005  [    0/ 3788]
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.146721
#
# Epoch 124
# -------------------------------
# loss: 0.173245  [    0/ 3788]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.146592
#
# Epoch 125
# -------------------------------
# loss: 0.169793  [    0/ 3788]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.145833
#
# Epoch 126
# -------------------------------
# loss: 0.169178  [    0/ 3788]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.144996
#
# Epoch 127
# -------------------------------
# loss: 0.161178  [    0/ 3788]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.143711
#
# Epoch 128
# -------------------------------
# loss: 0.167294  [    0/ 3788]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.142886
#
# Epoch 129
# -------------------------------
# loss: 0.161953  [    0/ 3788]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.141904
#
# Epoch 130
# -------------------------------
# loss: 0.167751  [    0/ 3788]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.141053
#
# Epoch 131
# -------------------------------
# loss: 0.160034  [    0/ 3788]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.140380
#
# Epoch 132
# -------------------------------
# loss: 0.159106  [    0/ 3788]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.138953
#
# Epoch 133
# -------------------------------
# loss: 0.165603  [    0/ 3788]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.136661
#
# Epoch 134
# -------------------------------
# loss: 0.156897  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.135655
#
# Epoch 135
# -------------------------------
# loss: 0.161743  [    0/ 3788]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.135318
#
# Epoch 136
# -------------------------------
# loss: 0.155070  [    0/ 3788]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.134070
#
# Epoch 137
# -------------------------------
# loss: 0.160375  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.131655
#
# Epoch 138
# -------------------------------
# loss: 0.157989  [    0/ 3788]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.129497
#
# Epoch 139
# -------------------------------
# loss: 0.160823  [    0/ 3788]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.128219
#
# Epoch 140
# -------------------------------
# loss: 0.155497  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127769
#
# Epoch 141
# -------------------------------
# loss: 0.159662  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.129010
#
# Epoch 142
# -------------------------------
# loss: 0.152360  [    0/ 3788]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.126801
#
# Epoch 143
# -------------------------------
# loss: 0.152252  [    0/ 3788]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.126825
#
# Epoch 144
# -------------------------------
# loss: 0.147774  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.125972
#
# Epoch 145
# -------------------------------
# loss: 0.137950  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125697
#
# Epoch 146
# -------------------------------
# loss: 0.150172  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.125512
#
# Epoch 147
# -------------------------------
# loss: 0.148577  [    0/ 3788]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.126443
#
# Epoch 148
# -------------------------------
# loss: 0.146415  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.126184
#
# Epoch 149
# -------------------------------
# loss: 0.141925  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124879
#
# Epoch 150
# -------------------------------
# loss: 0.138847  [    0/ 3788]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.123132
#
# Epoch 151
# -------------------------------
# loss: 0.143342  [    0/ 3788]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.121636
#
# Epoch 152
# -------------------------------
# loss: 0.146249  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.121074
#
# Epoch 153
# -------------------------------
# loss: 0.151392  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.122380
#
# Epoch 154
# -------------------------------
# loss: 0.143067  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.122022
#
# Epoch 155
# -------------------------------
# loss: 0.145139  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.120411
#
# Epoch 156
# -------------------------------
# loss: 0.137410  [    0/ 3788]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.117346
#
# Epoch 157
# -------------------------------
# loss: 0.139790  [    0/ 3788]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.116007
#
# Epoch 158
# -------------------------------
# loss: 0.134942  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.114235
#
# Epoch 159
# -------------------------------
# loss: 0.137094  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.113002
#
# Epoch 160
# -------------------------------
# loss: 0.145435  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.111245
#
# Epoch 161
# -------------------------------
# loss: 0.139045  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110079
#
# Epoch 162
# -------------------------------
# loss: 0.132776  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110577
#
# Epoch 163
# -------------------------------
# loss: 0.142604  [    0/ 3788]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.112050
#
# Epoch 164
# -------------------------------
# loss: 0.135142  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.113343
#
# Epoch 165
# -------------------------------
# loss: 0.134580  [    0/ 3788]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.113089
#
# Epoch 166
# -------------------------------
# loss: 0.138776  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.110671
#
# Epoch 167
# -------------------------------
# loss: 0.135368  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.108908
#
# Epoch 168
# -------------------------------
# loss: 0.129116  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.108434
#
# Epoch 169
# -------------------------------
# loss: 0.133832  [    0/ 3788]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.110139
#
# Epoch 170
# -------------------------------
# loss: 0.136329  [    0/ 3788]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.110253
#
# Epoch 171
# -------------------------------
# loss: 0.131792  [    0/ 3788]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.106563
#
# Epoch 172
# -------------------------------
# loss: 0.132869  [    0/ 3788]
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.104576
#
# Epoch 173
# -------------------------------
# loss: 0.137039  [    0/ 3788]
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.104701
#
# Epoch 174
# -------------------------------
# loss: 0.127300  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.105890
#
# Epoch 175
# -------------------------------
# loss: 0.126106  [    0/ 3788]
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.106775
#
# Epoch 176
# -------------------------------
# loss: 0.130399  [    0/ 3788]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.106204
#
# Epoch 177
# -------------------------------
# loss: 0.128730  [    0/ 3788]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.105932
#
# Epoch 178
# -------------------------------
# loss: 0.121156  [    0/ 3788]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.106307
#
# Epoch 179
# -------------------------------
# loss: 0.120880  [    0/ 3788]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.106518
#
# Epoch 180
# -------------------------------
# loss: 0.125021  [    0/ 3788]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.106285
#
# Epoch 181
# -------------------------------
# loss: 0.129722  [    0/ 3788]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.103978
#
# Epoch 182
# -------------------------------
# loss: 0.126689  [    0/ 3788]
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.102386
#
# Epoch 183
# -------------------------------
# loss: 0.127964  [    0/ 3788]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.101866
#
# Epoch 184
# -------------------------------
# loss: 0.122348  [    0/ 3788]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.101787
#
# Epoch 185
# -------------------------------
# loss: 0.123429  [    0/ 3788]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.101295
#
# Epoch 186
# -------------------------------
# loss: 0.126502  [    0/ 3788]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.099380
#
# Epoch 187
# -------------------------------
# loss: 0.120383  [    0/ 3788]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.097397
#
# Epoch 188
# -------------------------------
# loss: 0.122581  [    0/ 3788]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.096745
#
# Epoch 189
# -------------------------------
# loss: 0.119232  [    0/ 3788]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.096016
#
# Epoch 190
# -------------------------------
# loss: 0.112660  [    0/ 3788]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.096484
#
# Epoch 191
# -------------------------------
# loss: 0.122470  [    0/ 3788]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.098906
#
# Epoch 192
# -------------------------------
# loss: 0.110970  [    0/ 3788]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.099126
#
# Epoch 193
# -------------------------------
# loss: 0.122324  [    0/ 3788]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.097303
#
# Epoch 194
# -------------------------------
# loss: 0.111280  [    0/ 3788]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.095488
#
# Epoch 195
# -------------------------------
# loss: 0.117589  [    0/ 3788]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.093508
#
# Epoch 196
# -------------------------------
# loss: 0.115179  [    0/ 3788]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.092784
#
# Epoch 197
# -------------------------------
# loss: 0.114686  [    0/ 3788]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.092811
#
# Epoch 198
# -------------------------------
# loss: 0.115566  [    0/ 3788]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.093444
#
# Epoch 199
# -------------------------------
# loss: 0.120369  [    0/ 3788]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.093471
#
# Epoch 200
# -------------------------------
# loss: 0.112876  [    0/ 3788]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.092744
#
# Done!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
hex_d1 = '#552a28'
hex_d2 = '#005943'

plt.figure()
plt.plot(train_loss, hex_d1, label='train loss')
plt.ylabel('train loss')
plt.xlabel('epoch')
plt.plot(valid_loss, hex_d2, label='valid loss')
plt.ylabel('valid loss')
plt.xlabel('epoch')
plt.legend()

plt.savefig(os.path.join(pic_dir, 'cnn_128_100e_loss.png'))
plt.show()
# Out:
# Done!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


plt.figure()
plt.plot(accuracy, color = '#550300', label='accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.savefig('cnn_128_100e_accuracy.png')
plt.show()
